# %%
import os
from d́otenv import load_dotenv
import openai
import pandas as pd
from geopy.distance import geodesic
import folium

# Load environment variables from .env file
load_dotenv()

# Set your OpenAI API key
openai.api_key = os.getenv("OPENAI_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 from d́otenv import load_dotenv
#       3 import openai
#       4 import pandas as pd
#
# ModuleNotFoundError: No module named 'd́otenv'
